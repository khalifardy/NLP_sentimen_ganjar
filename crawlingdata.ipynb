# %%
#ec9e24b4c570cbc8fe7e48875bfcdb588152022a
import pandas as pd

# %%
dataku = pd.read_csv("raw/ganjar.csv",delimiter=";")
dataku.tail()
# Out:
#                          created_at               id_str  \
# 703  Sun Aug 27 10:13:07 +0000 2023  1695741222575559013
# 704  Sun Aug 27 10:13:03 +0000 2023  1695741204334534945
# 705  Sun Aug 27 10:12:35 +0000 2023  1695741089532313799
# 706  Sun Aug 27 10:12:26 +0000 2023  1695741052639191183
# 707  Sun Aug 27 10:12:26 +0000 2023  1695741049698910247
#
#                                              full_text  quote_count  \
# 703  Ganjar Pranowo menjadi mentor pembangunan daer...            2
# 704  Hadiri silaturahmi Masyayikh se-indonesia, Gan...            0
# 705  Ganjar ajak seruduk mereka2 penghambat kemajua...            0
# 706  Ganjar pranowo dorong kebutuhan PPPK guru dapa...            0
# 707  Ganjar Pranowo memaparkan program kerja pada a...            0
#
#      reply_count  retweet_count  favorite_count lang          user_id_str  \
# 703            4             12              21   in  1680910624048676864
# ...
